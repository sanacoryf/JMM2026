# %%
import pandas as pd
import seaborn as sns
urlCSV = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ0QcCiSBeeuIzuKGMg4MtOCtQGuzos-uEPOrZGPUbl0v37_zIBSoK5cQG4lt21rTlg-k9JqRuyjnkA/pub?gid=161555812&single=true&output=csv"
df = pd.read_csv(urlCSV, usecols=range(1,17))
df.set_index(df.columns[0], inplace=True)

# %%
newrows = []

#From df we create the peopleSim score table
for index, row in df.iterrows():
    normrow = sum([x**2 for x in row] )**0.5
    newrow = [x/normrow for x in row]
    newrows.append(newrow)

Adf = pd.DataFrame(newrows)
ATdf = Adf.transpose()
peopleSim = Adf @ ATdf
peopleSim.index = df.index
peopleSim.columns = df.index

# %%
df
# Out:
#                     Beyonce  Mickey Guyton  Justin Bieber  One Direction  \
# Your Name
# Frank                     8              5              2              2
# Random Music Lover        8              5              7              5
#
#                     The Beatles  Led Zeppelin  Rhianna  WIllie Nelson  \
# Your Name
# Frank                         9            10        6              8
# Random Music Lover            1             9        9              3
#
#                     Fallout Boy  Kendrick Lamar  Jimi Hendrix  \
# Your Name
# Frank                         6               6            10
# Random Music Lover            2               8             4
#
#                     Mozart/Classical Music  Taylor Swift  Tom Waits  \
# Your Name
# Frank                                    6             5          9
# Random Music Lover                       2             9          3
#
#                     Ed Sheeran
# Your Name
# Frank                        5
# Random Music Lover           6

# %%
#From df we create the musicSim score table
newrows = []
for index, row in df.transpose().iterrows():
    normrow = sum([x**2 for x in row] )**0.5
    newrow = [x/normrow for x in row]
    newrows.append(newrow)

Bdf = pd.DataFrame(newrows)
BTdf = Bdf.transpose()
musicSim = Bdf @ BTdf
musicSim.index = df.columns
musicSim.columns = df.columns

# %%
ax = sns.heatmap(peopleSim, annot=True)
fig = ax.get_figure()
fig.show()
fig.savefig("musicpeople.png")

# %%
ax = sns.heatmap(musicSim, annot=True)
fig = ax.get_figure()
fig.show()
fig.savefig("music.png")

# %%
peopleSim
# Out:
# Your Name              Frank  Random Music Lover
# Your Name
# Frank               1.000000            0.803313
# Random Music Lover  0.803313            1.000000

# %%
musicSim
# Out:
#                          Beyonce  Mickey Guyton  Justin Bieber  One Direction  \
# Beyonce                 1.000000       1.000000       0.874157       0.919145
# Mickey Guyton           1.000000       1.000000       0.874157       0.919145
# Justin Bieber           0.874157       0.874157       1.000000       0.994781
# One Direction           0.919145       0.919145       0.994781       1.000000
# The Beatles             0.780869       0.780869       0.379223       0.471652
# Led Zeppelin            0.998618       0.998618       0.847424       0.897171
# Rhianna                 0.980581       0.980581       0.952424       0.978550
# WIllie Nelson           0.910366       0.910366       0.594843       0.673754
# Fallout Boy             0.894427       0.894427       0.564684       0.645942
# Kendrick Lamar          0.989949       0.989949       0.934052       0.965616
# Jimi Hendrix            0.919145       0.919145       0.612173       0.689655
# Mozart/Classical Music  0.894427       0.894427       0.564684       0.645942
# Taylor Swift            0.961524       0.961524       0.973940       0.991998
# Tom Waits               0.894427       0.894427       0.564684       0.645942
# Ed Sheeran              0.995893       0.995893       0.914535       0.951034
